# %%
from Libraries.Json_Parser import sanitize_and_parse_critic

txt = r"""
{
  "scoring": {
    "factuality": <1-5>,
    "clarity": <1-5>,
    "logical_coherence": <1-5>,
    "coverage": <1-5>,
    "utility": <1-5>,
    "consistency": <1-5>
  },
  "feedback_text": "ý 1, ngắn gọn, kiểm chứng đúng"
}

"""

print(sanitize_and_parse_critic(txt))
# Out:
# {'scoring': {'factuality': 3, 'clarity': 3, 'logical_coherence': 3, 'coverage': 3, 'utility': 3, 'consistency': 3}, 'feedback_text': 'ý 1, ngắn gọn, kiểm chứng đúng'}
