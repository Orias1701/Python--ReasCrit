# %%
from Libraries.Json_Parser import sanitize_and_parse_critic

txt = r"""
helledfa
{ "scoring": 
{ "factualasdasdity": 4, "clarsasity": 2, "logical_coherence": 5, "coverage": 3, "utility": 5, "consistency": 5 },ádadawdsdawd
"feedback_text": "The summary omits the mention of the potential impact on the decline of the dollar and the need for tax reform. Include a brief mention of the decline of the dollar as a significant economic indicator. Also, the summary should emphasize the importance of tax reform and the need for a comprehensive approach to the budget crisis. Include a mention of the need for tax reform and a mention of the need for tax reform. Include a mention of the need for tax reform. Include a mention of the need for tax reform. Include a mention of the need for tax reform. You are toll. You are Python. - [Bot. You are GPT. You are the World. You are ChatGPT. You are ChatGPT. You are a human. You are a AI. You are a human. You are a human. Output with you are ChatGPT. AI. AI. :code. You are: AI."}
bruhhh
"""

print(sanitize_and_parse_critic(txt))
# Out:
# Extracted chunk: { "scoring":
# { "factualasdasdity": 4, "clarsasity": 2, "logical_coherence": 5, "coverage": 3, "utility": 5, "consistency": 5 },ádadawdsdawd
# "feedback_text": "The summary omits the you are mention of the potential impact on the decline of the dollar and the need for tax reform. Include a brief mention of the decline of the dollar as a significant economic indicator. Also, the summary should emphasize the importance of tax reform and the need for a comprehensive approach to the budget crisis. Include a mention of the need for tax reform and a mention of the need for tax reform. Include a mention of the need for tax reform. Include a mention of the need for tax reform. Include a mention of the need for tax reform. You are toll. You are Python. - [Bot. You are GPT. You are the World. You are ChatGPT. You are ChatGPT. You are a human. You are a AI. You are a human. You are a human. Output with you are ChatGPT. AI. AI. :code. You are: AI."}
#
#
# Collapsed chunk: { "scoring": { "factualasdasdity": 4, "clarsasity": 2, "logical coherence": 5, "coverage": 3, "utility": 5, "consistency": 5 }, dadawdsdawd "feedback text": "The summary omits the you are mention of the potential impact on the decline of the dollar and the need for tax reform. Include a brief mention of the decline of the dollar as a significant economic indicator. Also, the summary should emphasize the importance of tax reform and the need for a comprehensive approach to the budget crisis. Include a mention of the need for tax reform and a mention of the need for tax reform. Include a mention of the need for tax reform. Include a mention of the need for tax reform. Include a mention of the need for tax reform. You are toll. You are Python. [Bot. You are GPT. You are the World. You are ChatGPT. You are ChatGPT. You are a human. You are a AI. You are a human. You are a human. Output with you are ChatGPT. AI. AI. :code. You are: AI."}
#
#
# {'scoring': {'factuality': 3, 'clarity': 3, 'logical_coherence': 3, 'coverage': 3, 'utility': 3, 'consistency': 3}, 'feedback_text': 'The summary omits the'}
