# %%
from Libraries.Json_Parser import sanitize_and_parse_critic

txt = r"""
helledfa
{ "scoring": 
{ "factualasdasdity": 4, "clarsasity": 2, "logical_coherence": 5, "coverage": 3, "utility": 5, "consistency": 5 },ádadawdsdawd
"feedback_text": "
tốt, 
The summary omits the mention of the potential impact on the decline of the dollar and the need for tax reform. 


Include a brief mention of the decline of the dollar as a significant economic indicator. Also, the summary should emphasize the importance of tax reform and the need for a comprehensive approach to the budget crisis. Include a mention of the need for tax reform and a mention of the need for tax reform. Include a mention of the need for tax reform. Include a mention of the need for tax reform. Include a mention of the need for tax reform. You are toll. You are Python. - [Bot. You are GPT. You are the World. You are ChatGPT. You are ChatGPT. You are a human. You are a AI. You are a human. You are a human. Output with you are ChatGPT. AI. AI. :code. You are: AI."}
bruhhh
"""

print(sanitize_and_parse_critic(txt))
# Out:
# {'scoring': {'factuality': 4, 'clarity': 2, 'logical_coherence': 5, 'coverage': 3, 'utility': 5, 'consistency': 5}, 'feedback_text': 'tốt, The summary omits the mention of the potential impact on the decline of the dollar and the need for tax reform. Include a brief mention of the decline of the dollar as a significant economic indicator. Also, the summary should emphasize the importance of tax reform and the need for a comprehensive approach to the budget crisis. Include a mention of the need for tax reform and a mention of the need for tax reform. Include a mention of the need for tax reform. Include a mention of the need for tax reform. Include a mention of the need for tax reform. You are toll. You are Python. [Bot. You are GPT. You are the World. You are ChatGPT. You are ChatGPT. You are a human. You are a AI. You are a human. You are a human. Output with you are ChatGPT. AI. AI. :code. You are: AI'}
